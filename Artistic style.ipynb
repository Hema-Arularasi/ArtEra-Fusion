# %%
import tensorflow as tf
import tensorflow_hub as hub
import cv2
import numpy as np
import os

# Set TensorFlow Hub cache directory
os.environ["TFHUB_CACHE_DIR"] = "C:/Users/ADMIN/Documents/tfhub_cache"

def load_img(path_to_img):
    img = tf.io.read_file(path_to_img)
    img = tf.image.decode_image(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = img[tf.newaxis, :]
    return img

def tensor_to_image(tensor):
    tensor = tensor*255
    tensor = np.array(tensor, dtype=np.uint8)
    if np.ndim(tensor) > 3:
        assert tensor.shape[0] == 1
        tensor = tensor[0]
    return tensor

def prompt_continue():
    while True:
        choice = input("Do you want to continue? (y/n): ").lower()
        if choice in ['y', 'yes']:
            return True
        elif choice in ['n', 'no']:
            return False
        else:
            print("Invalid choice. Please enter 'y' or 'n'.")

def select_artistic_style():
    print("Select an artistic style:")
    print("1. Bold strokes of Van Gogh")
    print("2. Geometric abstraction of Picasso")
    # Add more styles as needed
    while True:
        choice = input("Enter the number corresponding to your choice: ")
        if choice == '1':
            return "https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/2"  # Van Gogh style URL
        elif choice == '2':
            return "https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/3"  # Picasso style URL
        # Add more conditions for additional styles
        else:
            print("Invalid choice. Please enter the number corresponding to the desired style.")

def main():
    while True:
        content_path = input("Enter the path of the content image: ")
        style_path = input("Enter the path of the style image: ")
        style_url = select_artistic_style()

        dog_image = load_img(content_path)
        style_image = load_img(style_path)

        # Convert TensorFlow tensors to NumPy arrays for display
        dog_np = tensor_to_image(dog_image.numpy())
        style_np = tensor_to_image(style_image.numpy())
        color = cv2.cvtColor(dog_np, cv2.COLOR_BGR2RGB)

        cv2.imshow('Content image', color)
        cv2.waitKey(0)
        cv2.destroyAllWindows()

        cv2.imshow('Style Image', style_np)
        cv2.waitKey(0)
        cv2.destroyAllWindows()

        # Load the style transfer model from TF Hub
        hub_model = hub.load('https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/2')

        # Apply style transfer
        stylized_image = hub_model(tf.constant(dog_image), tf.constant(style_image))[0]

        # Convert the stylized image tensor to a NumPy array for display
        op = tensor_to_image(stylized_image)

        # Convert RGB to BGR for OpenCV display
        op_bgr = cv2.cvtColor(op, cv2.COLOR_RGB2BGR)

        # Display the stylized image
        cv2.imshow('Stylized Image', op_bgr)
        cv2.waitKey(0)
        cv2.destroyAllWindows()

        if not prompt_continue():
            break

if __name__ == "__main__":
    main()
# Out:
# Enter the path of the content image: D:/ArtEra Fusion/content1.jpg
# Enter the path of the style image: D:/ArtEra Fusion/pattern.jpg
# Select an artistic style:
# 1. Bold strokes of Van Gogh
# 2. Geometric abstraction of Picasso
# Enter the number corresponding to your choice: 2
# Do you want to continue? (y/n): n

# %%
import tensorflow as tf
import tensorflow_hub as hub
import cv2
import numpy as np
import os

# Set TensorFlow Hub cache directory
os.environ["TFHUB_CACHE_DIR"] = "C:/Users/ADMIN/Documents/tfhub_cache"

def load_img(path_to_img):
    img = tf.io.read_file(path_to_img)
    img = tf.image.decode_image(img, channels=3)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = img[tf.newaxis, :]
    return img

def tensor_to_image(tensor):
    tensor = tensor*255
    tensor = np.array(tensor, dtype=np.uint8)
    if np.ndim(tensor) > 3:
        assert tensor.shape[0] == 1
        tensor = tensor[0]
    return tensor

def prompt_continue():
    while True:
        choice = input("Do you want to continue? (y/n): ").lower()
        if choice in ['y', 'yes']:
            return True
        elif choice in ['n', 'no']:
            return False
        else:
            print("Invalid choice. Please enter 'y' or 'n'.")

def select_artistic_style():
    print("Select an artistic style:")
    print("1. Bold strokes of Van Gogh")
    print("2. Geometric abstraction of Picasso")
    # Add more styles as needed
    while True:
        choice = input("Enter the number corresponding to your choice: ")
        if choice == '1':
            return "https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/2"  # Van Gogh style URL
        elif choice == '2':
            return "https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/3"  # Picasso style URL
        # Add more conditions for additional styles
        else:
            print("Invalid choice. Please enter the number corresponding to the desired style.")

def main():
    while True:
        content_path = input("Enter the path of the content image: ")
        style_path = input("Enter the path of the style image: ")
        style_url = select_artistic_style()

        content_image = load_img(content_path)
        style_image = load_img(style_path)

        # Convert TensorFlow tensors to NumPy arrays for display
        content_np = tensor_to_image(content_image.numpy())
        style_np = tensor_to_image(style_image.numpy())
        color = cv2.cvtColor(content_np, cv2.COLOR_BGR2RGB)

        cv2.imshow('Content image', color)
        cv2.waitKey(0)
        cv2.destroyAllWindows()

        cv2.imshow('Style Image', style_np)
        cv2.waitKey(0)
        cv2.destroyAllWindows()

        # Load the style transfer model from TF Hub
        hub_model = hub.load('https://tfhub.dev/google/magenta/arbitrary-image-stylization-v1-256/2')

        # Apply style transfer
        stylized_image = hub_model(tf.constant(content_image), tf.constant(style_image))[0]

        # Convert the stylized image tensor to a NumPy array for display
        op = tensor_to_image(stylized_image)

        # Convert RGB to BGR for OpenCV display
        op_bgr = cv2.cvtColor(op, cv2.COLOR_RGB2BGR)

        # Display the stylized image
        cv2.imshow('Stylized Image', op_bgr)
        cv2.waitKey(0)
        cv2.destroyAllWindows()

        if not prompt_continue():
            break

if __name__ == "__main__":
    main()
# Out:
# Enter the path of the content image: D:/ArtEra Fusion/content1.jpg
# Enter the path of the style image: D:/ArtEra Fusion/patterns.png
# Select an artistic style:
# 1. Bold strokes of Van Gogh
# 2. Geometric abstraction of Picasso
# Enter the number corresponding to your choice: 1
# Do you want to continue? (y/n): n

# %%
"D:\ArtEra Fusion\patterns.png"
